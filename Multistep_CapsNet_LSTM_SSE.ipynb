# %% [markdown]
# <a href="https://colab.research.google.com/github/Zhang-Cheng-76200/Multistep-forecasting-CapsNet-LSTM/blob/main/Multistep_CapsNet_LSTM_SSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multistage prediction with CAPSNET-LSTM (SSE)

# %%
import keras.backend as K
import tensorflow as tf

import keras
from keras import backend as K
from keras import initializers, layers, models, optimizers, callbacks, utils
from keras.models import load_model
from keras.models import model_from_json

from keras.initializers import glorot_uniform

from keras.initializers import *
from keras.layers import *
from keras.models import *
from keras.optimizers import *
from keras.callbacks import EarlyStopping
from keras.utils import *

from keras import losses
from keras.utils.io_utils import ask_to_proceed_with_overwrite
from tensorflow.python.platform import tf_logging as logging

import os
import copy
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dataclasses import dataclass

# %%
import random

# %%
# Set seed
from numpy.random import seed
seed(1)
tf.random.set_seed(1)

# %%
# If code is running on TPU
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
print(tf.__version__)
# Out:
# 2.11.0

# %% [markdown]
# # Parsing the raw data
#
# A couple of things to note:
#
# - There is no need to save the data points as numpy arrays, regular lists is fine.
# - The `time` list should contain every timestep (starting at zero), which is just a sequence of ordered numbers with the same length as the `series` list.
# - The values of the `series` should be of `float` type. You can use Python's built-in `float` function to ensure this.

# %% [markdown]
# Begin by looking at the structure of the xlsx file that contains the data:

# %%
from google.colab import drive
drive.mount ('gdrive')
# Out:
# Mounted at gdrive

# %%
SSE_raw = pd.read_excel('/content/gdrive/MyDrive/Multistage/SSE/SSE.xlsx')
SSE_raw
# Out:
#            Date         Open         High          Low        Close  \
# 0    2010-01-04  3289.750000  3295.279053  3243.319092  3243.760010
# 1    2010-01-05  3254.468018  3290.511963  3221.461914  3282.178955
# 2    2010-01-06  3277.517090  3295.867920  3253.043945  3254.215088
# 3    2010-01-07  3253.990967  3268.819092  3176.707031  3192.775879
# 4    2010-01-08  3177.259033  3198.919922  3149.017090  3195.997070
# ...         ...          ...          ...          ...          ...
# 2422 2019-12-25  2980.427979  2988.291992  2970.656982  2981.881104
# 2423 2019-12-26  2981.249023  3007.354980  2980.396973  3007.354980
# 2424 2019-12-27  3006.852051  3036.113037  3003.631104  3005.035889
# 2425 2019-12-30  2998.168945  3041.396973  2983.343994  3040.023926
# 2426 2019-12-31  3036.385986  3051.677002  3030.511963  3050.124023
#
#         Adj Close  Volume
# 0     3243.760010  109400
# 1     3282.178955  126200
# 2     3254.215088  123600
# 3     3192.775879  128600
# 4     3195.997070   98400
# ...           ...     ...
# 2422  2981.881104  175700
# 2423  3007.354980  182400
# 2424  3005.035889  247100
# 2425  3040.023926  248100
# 2426  3050.124023  217400
#
# [2427 rows x 7 columns]

# %%
series = SSE_raw.iloc[:,4] # close price

# %%
time = []
for i in range(0, len(series)):
  time.append(i)

# %% [markdown]
# A helper function to plot the time series:

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %% [markdown]
# The next cell will use functions to compute the `time` and `series` and will save these as numpy arrays within the `G` dataclass. This cell will also plot the time series:

# %%
# Save all "global" variables within the G class (G stands for global)
@dataclass
class G:
    TIME = np.array(time)
    SERIES = np.array(series)
    SPLIT_TIME = int(len(series)*0.1)          # data splitting, the last 20% samples are test set.
    WINDOW_SIZE = 50                                # sequence length
    BATCH_SIZE = 32                                  # batch size

plt.rcParams['font.size'] = '16'
plt.figure(figsize=(10, 6))
plot_series(G.TIME, G.SERIES)
plt.ylabel("Index Value")
plt.xlabel("Time Step")
legend_drawn_flag = True
plt.legend(["SSE"], loc=0, frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/SSE_original.tif")
plt.show()

# %%
series_y = series[G.WINDOW_SIZE:]

# %% [markdown]
# # Processing the data
#
# The `train_test_split` and `windowed_dataset` functions:

# %%
def train_test_split(time, series, time_step=G.SPLIT_TIME):

    time_train = time[:-G.SPLIT_TIME]
    series_train = series[:-G.SPLIT_TIME]
    time_test = time[-G.SPLIT_TIME:]
    series_test = series[-G.SPLIT_TIME:]

    return time_train, series_train, time_test, series_test

# %%
time_train, series_train, time_test, series_test = train_test_split(G.TIME, series)

# %%
# Split the dataset
time_train, series_train, time_test, series_test = train_test_split(G.TIME, G.SERIES)

# %%
def min_max_normalization(series):
  series = (series - min(series[:-G.SPLIT_TIME]))/(max(series[:-G.SPLIT_TIME]) - min(series[:-G.SPLIT_TIME]))
  return series

# %%
series_norm = min_max_normalization(G.SERIES)

# %%
# Create train_set, val_set, and train_val_set. train_set and val_set are used for hyper=parameters tuning, and train_val_set is used for training.
def windowed_dataset_one_step(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    ds = ds.batch(batch_size).prefetch(1)
    return ds

# %%
def windowed_dataset_five_step(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 5, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 5))
    ds = ds.map(lambda w: (w[:-5], w[-5:]))
    ds = ds.batch(batch_size).prefetch(1)
    return ds

# %%
train_set_five_step = windowed_dataset_five_step(series_norm[:-G.SPLIT_TIME], window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
train_set_one_step = windowed_dataset_one_step(series_norm[:-G.SPLIT_TIME], window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE)

# %%
def compute_metrics(true_series, forecast):
    
    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()   
    rmse = tf.math.sqrt(mse).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()
    mape = tf.keras.metrics.mean_absolute_percentage_error(true_series, forecast).numpy()
    return rmse, mae, mape

# %%
def smape(actual, predicted):
    """
    Calculates the Symmetric Mean Absolute Percentage Error (SMAPE) between two lists of values.
    """
    if len(actual) != len(predicted):
        raise ValueError("Lists must have the same length")
    return 100/len(actual) * sum(2 * abs(a - p) / (abs(a) + abs(p)) for a, p in zip(actual, predicted))

# %%
def model_forecast(model, series, window_size):
  ds = tf.data.Dataset.from_tensor_slices(series)
  ds = ds.window(window_size, shift=1, drop_remainder=True)
  ds = ds.flat_map(lambda w: w.batch(window_size))
  ds = ds.batch(32).prefetch(1)
  forecast = model.predict(ds)
  return forecast

# %%
def reverse_normalization(series, series_train):
  series = series * (max(series_train) - min(series_train)) + min(series_train)
  return series

# %%
# Prepare callback

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='mae', factor=0.95,patience=5)

# %%
input_shape = (G.WINDOW_SIZE, 1)

# %%
K.clear_session()

# %% [markdown]
# # Compiling the model

# %% [markdown]
# ## Defining the model architecture (CapsNet-LSTM)

# %%
# Squash function

def squash(vectors, axis=-1):
    """
    The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
    :param vectors: some vectors to be squashed, N-dim tensor
    :param axis: the axis to squash
    :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True) 
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
# Dynamic routing (layer)
#    The capsule layer. It is similar to Dense layer. Dense layer has `in_num` inputs, each is a scalar, the output of the 
#    neuron from the former layer, and it has `out_num` output neurons. CapsuleLayer just expand the output of the neuron
#    from scalar to vector. So its input shape = [None, input_num_capsule, input_dim_capsule] and output shape = \
#    [None, num_capsule, dim_capsule]. For Dense Layer, input_dim_capsule = dim_capsule = 1.

#    :param dim_capsule: dimension of the output vectors of the capsules in this layer
#    :param routings: number of iterations for the routing algorithm 

#@tf.keras.utils.register_keras_serializable() should use this line next time when need to save the model with a custom layer.
class Routing(keras.layers.Layer):

    def __init__(self, dim_capsule = 32 , routings=3, kernel_initializer='glorot_uniform'):
        super(Routing, self).__init__()
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.kernel_initializer = initializers.get(kernel_initializer)

    def build(self, input_shape):
        # build tansform matrix which can convert one primary cap to a vector with the same order as the digit cap.
        # assert len(input_shape) >= 3  # The input Tensor should have shape=[None, input_num_capsule, input_dim_capsule]
        self.input_num_capsule = input_shape[1]
        self.input_dim_capsule = input_shape[2]
        
        # Transform matrix
       
        self.W = self.add_weight(shape=[self.input_num_capsule,self.dim_capsule, self.input_dim_capsule],initializer=self.kernel_initializer,name='W')

    def call(self, inputs): #training=None
        # inputs.shape=[input_num_capsule, input_dim_capsule]
        # inputs_expand.shape=[input_num_capsule, input_dim_capsule, 1]
        inputs_expand = K.expand_dims(inputs, -1)    

        # Compute `inputs * W` by scanning inputs_tiled on dimension 0.
        # x.shape=[None, input_num_capsule, input_dim_capsule, 1]
        # W.shape=[input_num_capsule, dim_capsule, input_dim_capsule]
        # Regard the first dimension as `batch` dimension,
        # then matmul: [dim_capsule, input_dim_capsule] x [input_dim_capsule, 1] -> [dim_capsule].
        # inputs_hat.shape = [None, input_num_capsule, dim_capsule, 1]     
          
        inputs_hat = K.map_fn(lambda x: K.batch_dot(self.W, x, [2, 1]), elems=inputs_expand) 

        inputs_hat = K.squeeze(inputs_hat, axis = -1)
        # inputs_hat.shape = [None, input_num_capsule, dim_capsule]
       
        # Begin: Routing algorithm ---------------------------------------------------------------------#
        # The prior for coupling coefficient, initialized as zeros.
        # b.shape = [None, self.input_num_capsule].
        b = tf.zeros(shape=[K.shape(inputs_hat)[0], self.input_num_capsule])
        
        assert self.routings > 0
        for i in range(self.routings):
            # c.shape=[batch_size, input_num_capsule]
            c = tf.nn.softmax(b, axis=-1)

            # c.shape =  [batch_size, input_num_capsule]
            # inputs_hat.shape=[batch_size, input_num_capsule, dim_capsule]
            # The first dimensions as `batch` dimension,
            # then matmal: [input_num_capsule] x [input_num_capsule, dim_capsule] -> [dim_capsule].
            # outputs.shape=[None, dim_capsule]
            
            #outputs = squash(K.batch_dot(c, inputs_hat, [1, 1])) 
            outputs = K.batch_dot(c, inputs_hat, [1, 1])

            if i < self.routings - 1:
                # outputs.shape =  [None, dim_capsule]
                # inputs_hat.shape=[None, input_num_capsule, dim_capsule]
                # The first dimension as `batch` dimension,
                # then matmal: [dim_capsule] x [input_num_capsule, dim_capsule]^T -> [input_num_capsule].
                # b.shape=[batch_size, input_num_capsule]
                b += K.batch_dot(outputs, inputs_hat, [1, 2])
       
        # End: Routing algorithm -----------------------------------------------------------------------#

        return outputs

    def compute_output_shape(self, input_shape):
        return tuple([None, self.dim_capsule])

    def get_config(self):
        config = super().get_config()
        config.update({
            "dim_capsule": self.dim_capsule,
            "routings": self.routings,
            "kernel_initializer": self.kernel_initializer,
        })
        return config

# %% [markdown]
# ### Model training

# %%
# Build the model with the default setting. LSTM units = 200, Convolution filters = 256, kernel size = 2, stride = 1, learning rate = 0.0005
def CapsNet_LSTM():
   
    input = tf.keras.layers.Input(shape=input_shape)
      
    # First layer
    conv1d_1 = tf.keras.layers.Conv1D(filters=256, kernel_size=2, strides=1, padding='causal', activation='relu', name = 'conv1d_1')(input)
          
    # Primary caps
  
    unsquashed_caps = tf.keras.layers.Reshape((G.WINDOW_SIZE, 32, 8))(conv1d_1)
    squashed_caps = tf.keras.layers.Lambda(squash)(unsquashed_caps)

    # Digit caps
     
    digit_caps = tf.keras.layers.TimeDistributed(Routing(dim_capsule = 256, routings = 3))(squashed_caps)

    # LSTM layer
    lstm = tf.keras.layers.LSTM(200)(digit_caps)

    # Dense layer

    output = tf.keras.layers.Dense(5)(lstm)

    model = keras.Model(inputs=input, outputs=output, name="capsnet_lstm")

    learning_rate = 0.0005
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate = learning_rate),
        loss=tf.keras.losses.MeanSquaredError(),
        metrics=["mae"])

    return model

# %% [markdown]
# epoch number for CapsNet-LSTM is 500.

# %%
with strategy.scope():
  capsnet_lstm = CapsNet_LSTM()
    # Fit with the entire dataset.
capsnet_lstm.fit(train_set_five_step, epochs=400,callbacks = [reduce_lr])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/keras/backend.py:7104: calling map_fn (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# Epoch 1/400
# 67/67 [==============================] - 12s 59ms/step - loss: 0.0481 - mae: 0.1519 - lr: 5.0000e-04
# Epoch 2/400
# 67/67 [==============================] - 2s 29ms/step - loss: 0.0339 - mae: 0.1272 - lr: 5.0000e-04
# Epoch 3/400
# 67/67 [==============================] - 2s 29ms/step - loss: 0.0302 - mae: 0.1217 - lr: 5.0000e-04
# Epoch 4/400
# 67/67 [==============================] - 2s 30ms/step - loss: 0.0251 - mae: 0.1062 - lr: 5.0000e-04
# Epoch 5/400
# 67/67 [==============================] - 2s 30ms/step - loss: 0.0195 - mae: 0.0883 - lr: 5.0000e-04
# Epoch 6/400
# 67/67 [==============================] - 2s 29ms/step - loss: 0.0138 - mae: 0.0785 - lr: 5.0000e-04
# Epoch 7/400
# 67/67 [==============================] - 2s 28ms/step - loss: 0.0086 - mae: 0.0682 - lr: 5.0000e-04
# Epoch 8/400
# 67/67 [==============================] - 2s 29ms/step - loss: 0.0048 - mae: 0.0530 - lr: 5.0000e-04
# Epoch 9/400
# 67/67 [==============================] - 2s 29ms/step - loss: 0.
-04 - mae: 0.0142 - lr: 3.6549e-05
# Epoch 356/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2738e-04 - mae: 0.0142 - lr: 3.6549e-05
# Epoch 357/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2791e-04 - mae: 0.0142 - lr: 3.6549e-05
# Epoch 358/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2719e-04 - mae: 0.0142 - lr: 3.4721e-05
# Epoch 359/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2725e-04 - mae: 0.0142 - lr: 3.4721e-05
# Epoch 360/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2628e-04 - mae: 0.0142 - lr: 3.4721e-05
# Epoch 361/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2679e-04 - mae: 0.0142 - lr: 3.4721e-05
# Epoch 362/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2684e-04 - mae: 0.0142 - lr: 3.4721e-05
# Epoch 363/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2703e-04 - mae: 0.0142 - lr: 3.2985e-05
# Epoch 364/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2618e-04 - mae: 0.0142 - lr: 3.2985e-05
# Epoch 365/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2678e-04 - mae: 0.0142 - lr: 3.2985e-05
# Epoch 366/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2625e-04 - mae: 0.0142 - lr: 3.2985e-05
# Epoch 367/400
# 67/67 [==============================] - 2s 31ms/step - loss: 4.2669e-04 - mae: 0.0142 - lr: 3.2985e-05
# Epoch 368/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2620e-04 - mae: 0.0142 - lr: 3.1336e-05
# Epoch 369/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2599e-04 - mae: 0.0142 - lr: 3.1336e-05
# Epoch 370/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2532e-04 - mae: 0.0141 - lr: 3.1336e-05
# Epoch 371/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2562e-04 - mae: 0.0142 - lr: 3.1336e-05
# Epoch 372/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2510e-04 - mae: 0.0141 - lr: 3.1336e-05
# Epoch 373/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2483e-04 - mae: 0.0142 - lr: 2.9769e-05
# Epoch 374/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2380e-04 - mae: 0.0141 - lr: 2.9769e-05
# Epoch 375/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2403e-04 - mae: 0.0142 - lr: 2.9769e-05
# Epoch 376/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2334e-04 - mae: 0.0141 - lr: 2.9769e-05
# Epoch 377/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2366e-04 - mae: 0.0142 - lr: 2.9769e-05
# Epoch 378/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2294e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 379/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2268e-04 - mae: 0.0142 - lr: 2.8281e-05
# Epoch 380/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2233e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 381/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2246e-04 - mae: 0.0142 - lr: 2.8281e-05
# Epoch 382/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2219e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 383/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2219e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 384/400
# 67/67 [==============================] - 2s 31ms/step - loss: 4.2221e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 385/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2198e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 386/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2248e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 387/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2239e-04 - mae: 0.0142 - lr: 2.8281e-05
# Epoch 388/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2252e-04 - mae: 0.0141 - lr: 2.6867e-05
# Epoch 389/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2221e-04 - mae: 0.0142 - lr: 2.6867e-05
# Epoch 390/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2216e-04 - mae: 0.0141 - lr: 2.6867e-05
# Epoch 391/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2186e-04 - mae: 0.0142 - lr: 2.6867e-05
# Epoch 392/400
# 67/67 [==============================] - 2s 31ms/step - loss: 4.2199e-04 - mae: 0.0141 - lr: 2.6867e-05
# Epoch 393/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2101e-04 - mae: 0.0141 - lr: 2.5523e-05
# Epoch 394/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.2065e-04 - mae: 0.0141 - lr: 2.5523e-05
# Epoch 395/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2030e-04 - mae: 0.0141 - lr: 2.5523e-05
# Epoch 396/400
# 67/67 [==============================] - 2s 29ms/step - loss: 4.1982e-04 - mae: 0.0141 - lr: 2.5523e-05
# Epoch 397/400
# 67/67 [==============================] - 2s 30ms/step - loss: 4.2006e-04 - mae: 0.0141 - lr: 2.5523e-05
# Epoch 398/400
# 67/67 [==============================] - 2s 31ms/step - loss: 4.1964e-04 - mae: 0.0141 - lr: 2.4247e-05
# Epoch 399/400
# 67/67 [==============================] - 2s 33ms/step - loss: 4.1922e-04 - mae: 0.0141 - lr: 2.4247e-05
# Epoch 400/400
# 67/67 [==============================] - 2s 33ms/step - loss: 4.1915e-04 - mae: 0.0141 - lr: 2.4247e-05

# %%
print(capsnet_lstm.summary())
# Out:
# Model: "capsnet_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50, 1)]           0
#
#  conv1d_1 (Conv1D)           (None, 50, 256)           768
#
#  reshape (Reshape)           (None, 50, 32, 8)         0
#
#  lambda (Lambda)             (None, 50, 32, 8)         0
#
#  time_distributed (TimeDistr  (None, 50, 256)          65536
#  ibuted)
#
#  lstm (LSTM)                 (None, 200)               365600
#
#  dense (Dense)               (None, 5)                 1005
#
# =================================================================
# Total params: 432,909
# Trainable params: 432,909
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Evaluating the forecast
#
# Now it is time to evaluate the performance of the forecast. For this we use the `compute_metrics` function:

# %% [markdown]
# At this point only the model that will perform the forecast is ready but we still need to compute the actual forecast.

# %% [markdown]
# Faster model forecasts
#
#
# - The dataset is windowed using `window_size` rather than `window_size + 1`
# - No shuffle should be used
# - No need to split the data into features and labels
# - A model is used to predict batches of the dataset

# %% [markdown]
# Now compute the actual forecast:

# %%
# Evaluate each model and the ensemble on the test set
# remember the last predicted value is not in the test set. It should be removed when producing y_hat series.

capsnet_lstm_pred =  model_forecast(capsnet_lstm, series_norm, G.WINDOW_SIZE).squeeze()
# Out:
# 75/75 [==============================] - 5s 23ms/step

# %%
capsnet_lstm_pred = reverse_normalization(capsnet_lstm_pred, series_train)

# %%
series_hat_capsnet_lstm = capsnet_lstm_pred

# %%
series_y_hat_capsnet_lstm = np.array(list(series_hat_capsnet_lstm[:-1]))

# %%
series_test = series_y[-G.SPLIT_TIME:]
series_test_hat_capsnet_lstm_1 = series_y_hat_capsnet_lstm[-G.SPLIT_TIME:,0]
series_test_hat_capsnet_lstm_2 = series_y_hat_capsnet_lstm[-G.SPLIT_TIME:-1,1]
series_test_hat_capsnet_lstm_3 = series_y_hat_capsnet_lstm[-G.SPLIT_TIME:-2,2]
series_test_hat_capsnet_lstm_4 = series_y_hat_capsnet_lstm[-G.SPLIT_TIME:-3,3]
series_test_hat_capsnet_lstm_5 = series_y_hat_capsnet_lstm[-G.SPLIT_TIME:-4,4]

# %%
# Plot the forecast

plt.figure(figsize=(10, 6))

plt.plot(np.arange( 1, len(time_test)+1 ), series_test, linestyle='-', color='blue')

plt.plot(np.arange( 1, len(time_test)+1 ), series_test_hat_capsnet_lstm_1, linestyle='-', color='Red')

plt.plot(np.arange( 3, len(time_test)+1 ), series_test_hat_capsnet_lstm_3, linestyle='--', color='Orange')

plt.plot(np.arange( 5, len(time_test)+1 ), series_test_hat_capsnet_lstm_5, linestyle=':', color='Green')

plt.ylabel("Index Value")
plt.xlabel("Time Step")
plt.title("SSE test set prediction with CapsNet-LSTM")
legend_drawn_flag = True
plt.legend(["Original Value (SSE)", "1 step forecasting","3-step forecasting","5-step forecasting"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/capsnet_lstm_forecasts_SSE.tif")

# %%
rmse_capsnet_lstm_1, mae_capsnet_lstm_1, mape_capsnet_lstm_1= compute_metrics(series_test, series_test_hat_capsnet_lstm_1)

print(f"rmse: {rmse_capsnet_lstm_1:.2f}, mae: {mae_capsnet_lstm_1:.2f} , mape: {mape_capsnet_lstm_1:.2f} for 1-step forecast")
# Out:
# rmse: 33.90, mae: 23.48 , mape: 0.80 for 1-step forecast

# %%
smape_capsnet_lstm_1 = smape(series_test, series_test_hat_capsnet_lstm_1)
print(f"smape: {smape_capsnet_lstm_1:.2f} for 1-step forecast")
# Out:
# smape: 0.80 for 1-step forecast

# %%
rmse_capsnet_lstm_2, mae_capsnet_lstm_2, mape_capsnet_lstm_2= compute_metrics(series_test[1:], series_test_hat_capsnet_lstm_2)

print(f"rmse: {rmse_capsnet_lstm_2:.2f}, mae: {mae_capsnet_lstm_2:.2f} , mape: {mape_capsnet_lstm_2:.2f} for 2-step forecast")
# Out:
# rmse: 49.02, mae: 35.85 , mape: 1.22 for 2-step forecast

# %%
smape_capsnet_lstm_2 = smape(series_test[1:], series_test_hat_capsnet_lstm_2)
print(f"smape: {smape_capsnet_lstm_2:.2f} for 2-step forecast")
# Out:
# smape: 1.22 for 2-step forecast

# %%
rmse_capsnet_lstm_3, mae_capsnet_lstm_3, mape_capsnet_lstm_3= compute_metrics(series_test[2:], series_test_hat_capsnet_lstm_3)

print(f"rmse: {rmse_capsnet_lstm_3:.2f}, mae: {mae_capsnet_lstm_3:.2f} , mape: {mape_capsnet_lstm_3:.2f} for 3-step forecast")
# Out:
# rmse: 60.94, mae: 45.11 , mape: 1.53 for 3-step forecast

# %%
smape_capsnet_lstm_3 = smape(series_test[2:], series_test_hat_capsnet_lstm_3)
print(f"smape: {smape_capsnet_lstm_3:.2f} for 3-step forecast")
# Out:
# smape: 1.53 for 3-step forecast

# %%
rmse_capsnet_lstm_4, mae_capsnet_lstm_4, mape_capsnet_lstm_4= compute_metrics(series_test[3:], series_test_hat_capsnet_lstm_4)

print(f"rmse: {rmse_capsnet_lstm_4:.2f}, mae: {mae_capsnet_lstm_4:.2f} , mape: {mape_capsnet_lstm_4:.2f} for 4-step forecast")
# Out:
# rmse: 71.97, mae: 52.32 , mape: 1.78 for 4-step forecast

# %%
smape_capsnet_lstm_4 = smape(series_test[3:], series_test_hat_capsnet_lstm_4)
print(f"smape: {smape_capsnet_lstm_4:.2f} for 4-step forecast")
# Out:
# smape: 1.78 for 4-step forecast

# %%
rmse_capsnet_lstm_5, mae_capsnet_lstm_5, mape_capsnet_lstm_5= compute_metrics(series_test[4:], series_test_hat_capsnet_lstm_5)

print(f"rmse: {rmse_capsnet_lstm_5:.2f}, mae: {mae_capsnet_lstm_5:.2f} , mape: {mape_capsnet_lstm_5:.2f} for 5-step forecast")
# Out:
# rmse: 81.51, mae: 59.64 , mape: 2.03 for 5-step forecast

# %%
smape_capsnet_lstm_5 = smape(series_test[4:], series_test_hat_capsnet_lstm_5)
print(f"smape: {smape_capsnet_lstm_5:.2f} for 5-step forecast")
# Out:
# smape: 2.03 for 5-step forecast

# %%
# Save_weights model

capsnet_lstm.save_weights("/content/gdrive/MyDrive/Multistage/SSE/models/capsnet_lstm_SSE_MIMO.h5", overwrite=True, save_format=None, options=None)

# %%
# Save predicted values

np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/capsnet_lstm_predicted_test_SSE_1.csv", 
           series_test_hat_capsnet_lstm_1.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/capsnet_lstm_predicted_test_SSE_2.csv", 
           series_test_hat_capsnet_lstm_2.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/capsnet_lstm_predicted_test_SSE_3.csv", 
           series_test_hat_capsnet_lstm_3.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/capsnet_lstm_predicted_test_SSE_4.csv", 
           series_test_hat_capsnet_lstm_4.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/capsnet_lstm_predicted_test_SSE_5.csv", 
           series_test_hat_capsnet_lstm_5.T, delimiter=",")


np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/capsnet_lstm_predicted_whole_SSE.csv", 
           series_y_hat_capsnet_lstm.T, delimiter=",")

# %% [markdown]
# # Baseline (LSTM, GRU, RNN, CNN-LSTM)

# %% [markdown]
# ## LSTM

# %%
# Build the model with the best hp.
def LSTM():
   
    model = tf.keras.models.Sequential([
          tf.keras.layers.LSTM(200, input_shape=[G.WINDOW_SIZE, 1]),
          tf.keras.layers.Dense(5)
    ])
    learning_rate = 0.0005
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=tf.keras.losses.MeanSquaredError(),
        metrics=["mae"])

    return model

# %% [markdown]
# ### Model training

# %%
with strategy.scope():
  lstm = LSTM()
    # Fit with the entire dataset.
lstm.fit(train_set_five_step, epochs=400,callbacks = [reduce_lr])
# Out:
# Epoch 1/400
# 67/67 [==============================] - 7s 34ms/step - loss: 0.0176 - mae: 0.0890 - lr: 5.0000e-04
# Epoch 2/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0062 - mae: 0.0515 - lr: 5.0000e-04
# Epoch 3/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0034 - mae: 0.0379 - lr: 5.0000e-04
# Epoch 4/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0021 - mae: 0.0289 - lr: 5.0000e-04
# Epoch 5/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0017 - mae: 0.0262 - lr: 5.0000e-04
# Epoch 6/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0017 - mae: 0.0269 - lr: 5.0000e-04
# Epoch 7/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0017 - mae: 0.0270 - lr: 5.0000e-04
# Epoch 8/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0017 - mae: 0.0271 - lr: 5.0000e-04
# Epoch 9/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0017 - mae: 0.0267 - lr: 5.0000e-04
# Epoch 10/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0016 - mae: 0.0263 - lr: 5.0000e-04
# Epoch 11/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0016 - mae: 0.0258 - lr: 4.7500e-04
# Epoch 12/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0015 - mae: 0.0249 - lr: 4.7500e-04
# Epoch 13/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0015 - mae: 0.0250 - lr: 4.7500e-04
# Epoch 14/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0014 - mae: 0.0249 - lr: 4.7500e-04
# Epoch 15/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0014 - mae: 0.0247 - lr: 4.7500e-04
# Epoch 16/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0014 - mae: 0.0245 - lr: 4.7500e-04
# Epoch 17/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0014 - mae: 0.0244 - lr: 4.7500e-04
# Epoch 18/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0014 - mae: 0.0241 - lr: 4.7500e-04
# Epoch 19/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0239 - lr: 4.7500e-04
# Epoch 20/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0013 - mae: 0.0237 - lr: 4.7500e-04
# Epoch 21/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0013 - mae: 0.0234 - lr: 4.7500e-04
# Epoch 22/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0012 - mae: 0.0232 - lr: 4.7500e-04
# Epoch 23/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0230 - lr: 4.7500e-04
# Epoch 24/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0012 - mae: 0.0228 - lr: 4.7500e-04
# Epoch 25/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0225 - lr: 4.7500e-04
# Epoch 26/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0225 - lr: 4.7500e-04
# Epoch 27/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0011 - mae: 0.0224 - lr: 4.7500e-04
# Epoch 28/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0011 - mae: 0.0222 - lr: 4.7500e-04
# Epoch 29/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0011 - mae: 0.0217 - lr: 4.7500e-04
# Epoch 30/400
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0011 - mae: 0.0221 - lr: 4.7500e-04
# Epoch 31/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0011 - mae: 0.0219 - lr: 4.7500e-04
# Epoch 32/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0240 - lr: 4.7500e-04
# Epoch 33/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0010 - mae: 0.0209 - lr: 4.7500e-04
# Epoch 34/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0011 - mae: 0.0221 - lr: 4.7500e-04
# Epoch 35/400
# 67/67 [==============================] - 1s 19ms/step - loss: 9.8587e-04 - mae: 0.0205 - lr: 4.7500e-04
# Epoch 36/400
# 67/67 [==============================] - 1s 19ms/step - loss: 9.8738e-04 - mae: 0.0210 - lr: 4.7500e-04
# Epoch 37/400
# 67/67 [==============================] - 1s 19ms/step - loss: 9.8661e-04 - mae: 0.0206 - lr: 4.7500e-04
# Epoch 38/400
# 67/67 [==============================] - 1s 19ms/step - loss: 9.7159e-04 - mae: 0.0209 - lr: 4.7500e-04
# Epoch 39/400
# 67/67 [==============================] - 1s 20ms/step - loss: 9.4279e-04 - mae: 0.0202 - lr: 4.7500e-04
# Epoch 40/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0010 - mae: 0.0217 - lr: 4.7500e-04
# Epoch 41/400
# 67/67 [==============================] - 1s 21ms/step - loss: 9.4082e-04 - mae: 0.0199 - lr: 4.7500e-04
# Epoch 42/400
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0010 - mae: 0.0215 - lr: 4.7500e-04
# Epoch 43/400
# 67/67 [==============================] - 1s 19ms/step - loss: 9.8309e-04 - mae: 0.0206 - lr: 4.7500e-04
# Epoch 44/400
# 67/67 [==============================] - 1s 19ms/step - loss: 9
400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.3555e-04 - mae: 0.0142 - lr: 3.6549e-05
# Epoch 367/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.3509e-04 - mae: 0.0142 - lr: 3.6549e-05
# Epoch 368/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.3448e-04 - mae: 0.0142 - lr: 3.6549e-05
# Epoch 369/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.3493e-04 - mae: 0.0142 - lr: 3.4721e-05
# Epoch 370/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3340e-04 - mae: 0.0141 - lr: 3.4721e-05
# Epoch 371/400
# 67/67 [==============================] - 1s 22ms/step - loss: 4.3414e-04 - mae: 0.0142 - lr: 3.4721e-05
# Epoch 372/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.3333e-04 - mae: 0.0141 - lr: 3.4721e-05
# Epoch 373/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.3463e-04 - mae: 0.0142 - lr: 3.4721e-05
# Epoch 374/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.3336e-04 - mae: 0.0141 - lr: 3.2985e-05
# Epoch 375/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3422e-04 - mae: 0.0142 - lr: 3.2985e-05
# Epoch 376/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3221e-04 - mae: 0.0141 - lr: 3.2985e-05
# Epoch 377/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3357e-04 - mae: 0.0142 - lr: 3.2985e-05
# Epoch 378/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3223e-04 - mae: 0.0141 - lr: 3.2985e-05
# Epoch 379/400
# 67/67 [==============================] - 1s 21ms/step - loss: 4.3261e-04 - mae: 0.0141 - lr: 3.1336e-05
# Epoch 380/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.3106e-04 - mae: 0.0141 - lr: 3.1336e-05
# Epoch 381/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3185e-04 - mae: 0.0141 - lr: 3.1336e-05
# Epoch 382/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3054e-04 - mae: 0.0141 - lr: 3.1336e-05
# Epoch 383/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.3178e-04 - mae: 0.0141 - lr: 3.1336e-05
# Epoch 384/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3034e-04 - mae: 0.0141 - lr: 3.1336e-05
# Epoch 385/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.3246e-04 - mae: 0.0141 - lr: 3.1336e-05
# Epoch 386/400
# 67/67 [==============================] - 1s 21ms/step - loss: 4.3024e-04 - mae: 0.0141 - lr: 2.9769e-05
# Epoch 387/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3190e-04 - mae: 0.0141 - lr: 2.9769e-05
# Epoch 388/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.2873e-04 - mae: 0.0141 - lr: 2.9769e-05
# Epoch 389/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3083e-04 - mae: 0.0141 - lr: 2.9769e-05
# Epoch 390/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.2853e-04 - mae: 0.0141 - lr: 2.9769e-05
# Epoch 391/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.3086e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 392/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.2833e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 393/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.2924e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 394/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.2809e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 395/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.2854e-04 - mae: 0.0141 - lr: 2.8281e-05
# Epoch 396/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.2795e-04 - mae: 0.0141 - lr: 2.6867e-05
# Epoch 397/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.2773e-04 - mae: 0.0141 - lr: 2.6867e-05
# Epoch 398/400
# 67/67 [==============================] - 1s 19ms/step - loss: 4.2681e-04 - mae: 0.0141 - lr: 2.6867e-05
# Epoch 399/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.2653e-04 - mae: 0.0141 - lr: 2.6867e-05
# Epoch 400/400
# 67/67 [==============================] - 1s 20ms/step - loss: 4.2631e-04 - mae: 0.0141 - lr: 2.6867e-05

# %%
print(lstm.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 200)               161600
#
#  dense_1 (Dense)             (None, 5)                 1005
#
# =================================================================
# Total params: 162,605
# Trainable params: 162,605
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Evaluating the forecast
#
# Now it is time to evaluate the performance of the forecast. For this we use the `compute_metrics` function:

# %% [markdown]
# At this point only the model that will perform the forecast is ready but we still need to compute the actual forecast.

# %% [markdown]
# Faster model forecasts
#
#
# - The dataset is windowed using `window_size` rather than `window_size + 1`
# - No shuffle should be used
# - No need to split the data into features and labels
# - A model is used to predict batches of the dataset

# %% [markdown]
# Now compute the actual forecast:

# %%
# Evaluate each model and the ensemble on the test set
# remember the last predicted value is not in the test set. It should be removed when producing y_hat series.

lstm_pred =  model_forecast(lstm, series_norm, G.WINDOW_SIZE).squeeze()
# Out:
# 75/75 [==============================] - 4s 18ms/step

# %%
lstm_pred = reverse_normalization(lstm_pred, series_train)

# %%
series_hat_lstm = lstm_pred

# %%
series_y_hat_lstm = np.array(list(series_hat_lstm[:-1]))

# %%
series_test = series_y[-G.SPLIT_TIME:]
series_test_hat_lstm_1 = series_y_hat_lstm[-G.SPLIT_TIME:,0]
series_test_hat_lstm_2 = series_y_hat_lstm[-G.SPLIT_TIME:-1,1]
series_test_hat_lstm_3 = series_y_hat_lstm[-G.SPLIT_TIME:-2,2]
series_test_hat_lstm_4 = series_y_hat_lstm[-G.SPLIT_TIME:-3,3]
series_test_hat_lstm_5 = series_y_hat_lstm[-G.SPLIT_TIME:-4,4]

# %%
# Plot the forecast

plt.figure(figsize=(10, 6))

plt.plot(np.arange( 1, len(time_test)+1 ), series_test, linestyle='-', color='blue')

plt.plot(np.arange( 1, len(time_test)+1 ), series_test_hat_lstm_1, linestyle='-', color='Red')

plt.plot(np.arange( 3, len(time_test)+1 ), series_test_hat_lstm_3, linestyle='--', color='Orange')

plt.plot(np.arange( 5, len(time_test)+1 ), series_test_hat_lstm_5, linestyle=':', color='Green')

plt.ylabel("Index Value")
plt.xlabel("Time Step")
plt.title("SSE test set prediction with LSTM")
legend_drawn_flag = True
plt.legend(["Original Value (SSE)", "1-step forecasting","3-step forecasting","5-step forecasting"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/lstm_forecasts_SSE.tif")

# %%
rmse_lstm_1, mae_lstm_1, mape_lstm_1= compute_metrics(series_test, series_test_hat_lstm_1)

print(f"rmse: {rmse_lstm_1:.2f}, mae: {mae_lstm_1:.2f} , mape: {mape_lstm_1:.2f} for 1-step forecast")
# Out:
# rmse: 34.21, mae: 23.45 , mape: 0.80 for 1-step forecast

# %%
smape_lstm_1= smape(series_test, series_test_hat_lstm_1)

print(f"smape: {smape_lstm_1:.2f} for 1-step forecast")
# Out:
# smape: 0.80 for 1-step forecast

# %%
rmse_lstm_2, mae_lstm_2, mape_lstm_2= compute_metrics(series_test[1:], series_test_hat_lstm_2)

print(f"rmse: {rmse_lstm_2:.2f}, mae: {mae_lstm_2:.2f} , mape: {mape_lstm_2:.2f} for 2-step forecast")
# Out:
# rmse: 49.53, mae: 36.11 , mape: 1.23 for 2-step forecast

# %%
smape_lstm_2= smape(series_test[1:], series_test_hat_lstm_2)

print(f"smape: {smape_lstm_2:.2f} for 2-step forecast")
# Out:
# smape: 1.23 for 2-step forecast

# %%
rmse_lstm_3, mae_lstm_3, mape_lstm_3= compute_metrics(series_test[2:], series_test_hat_lstm_3)

print(f"rmse: {rmse_lstm_3:.2f}, mae: {mae_lstm_3:.2f} , mape: {mape_lstm_3:.2f} for 3-step forecast")
# Out:
# rmse: 61.55, mae: 45.43 , mape: 1.54 for 3-step forecast

# %%
smape_lstm_3= smape(series_test[2:], series_test_hat_lstm_3)

print(f"smape: {smape_lstm_3:.2f} for 3-step forecast")
# Out:
# smape: 1.54 for 3-step forecast

# %%
rmse_lstm_4, mae_lstm_4, mape_lstm_4= compute_metrics(series_test[3:], series_test_hat_lstm_4)

print(f"rmse: {rmse_lstm_4:.2f}, mae: {mae_lstm_4:.2f} , mape: {mape_lstm_4:.2f} for 4-step forecast")
# Out:
# rmse: 72.68, mae: 53.29 , mape: 1.81 for 4-step forecast

# %%
smape_lstm_4= smape(series_test[3:], series_test_hat_lstm_4)

print(f"smape: {smape_lstm_4:.2f} for 4-step forecast")
# Out:
# smape: 1.81 for 4-step forecast

# %%
rmse_lstm_5, mae_lstm_5, mape_lstm_5= compute_metrics(series_test[4:], series_test_hat_lstm_5)

print(f"rmse: {rmse_lstm_5:.2f}, mae: {mae_lstm_5:.2f} , mape: {mape_lstm_5:.2f} for 5-step forecast")
# Out:
# rmse: 82.19, mae: 59.79 , mape: 2.03 for 5-step forecast

# %%
smape_lstm_5= smape(series_test[4:], series_test_hat_lstm_5)

print(f"smape: {smape_lstm_5:.2f} for 5-step forecast")
# Out:
# smape: 2.04 for 5-step forecast

# %%
# Save_weights model

lstm.save_weights("/content/gdrive/MyDrive/Multistage/SSE/models/lstm_SSE_MIMO.h5", overwrite=True, save_format=None, options=None)

# %%
# Save predicted values

np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/lstm_predicted_test_SSE_1.csv", 
           series_test_hat_lstm_1.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/lstm_predicted_test_SSE_2.csv", 
           series_test_hat_lstm_2.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/lstm_predicted_test_SSE_3.csv", 
           series_test_hat_lstm_3.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/lstm_predicted_test_SSE_4.csv", 
           series_test_hat_lstm_4.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/lstm_predicted_test_SSE_5.csv", 
           series_test_hat_lstm_5.T, delimiter=",")


np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/lstm_predicted_whole_SSE.csv", 
           series_y_hat_lstm.T, delimiter=",")

# %% [markdown]
# ## RNN

# %%
# Build the model with the best hp.
def RNN():
   
    model = tf.keras.models.Sequential([
          tf.keras.layers.SimpleRNN(200, input_shape=[G.WINDOW_SIZE, 1]),
          tf.keras.layers.Dense(5)
    ])
    learning_rate = 0.0005
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=tf.keras.losses.MeanSquaredError(),
        metrics=["mae"])

    return model

# %% [markdown]
# ### Model training

# %%
with strategy.scope():
  rnn = RNN()
    # Fit with the entire dataset.
rnn.fit(train_set_five_step, epochs=400,callbacks = [reduce_lr])
# Out:
# Epoch 1/400
# 67/67 [==============================] - 5s 26ms/step - loss: 0.0199 - mae: 0.0918 - lr: 5.0000e-04
# Epoch 2/400
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0176 - mae: 0.0828 - lr: 5.0000e-04
# Epoch 3/400
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0119 - mae: 0.0724 - lr: 5.0000e-04
# Epoch 4/400
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0179 - mae: 0.0855 - lr: 5.0000e-04
# Epoch 5/400
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0092 - mae: 0.0622 - lr: 5.0000e-04
# Epoch 6/400
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0095 - mae: 0.0661 - lr: 5.0000e-04
# Epoch 7/400
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0035 - mae: 0.0398 - lr: 5.0000e-04
# Epoch 8/400
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0035 - mae: 0.0377 - lr: 5.0000e-04
# Epoch 9/400
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0017 - mae: 0.0269 - lr: 5.0000e-04
# Epoch 10/400
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0012 - mae: 0.0221 - lr: 5.0000e-04
# Epoch 11/400
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - mae: 0.0212 - lr: 5.0000e-04
# Epoch 12/400
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0010 - mae: 0.0211 - lr: 5.0000e-04
# Epoch 13/400
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0010 - mae: 0.0209 - lr: 5.0000e-04
# Epoch 14/400
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0010 - mae: 0.0208 - lr: 5.0000e-04
# Epoch 15/400
# 67/67 [==============================] - 1s 17ms/step - loss: 9.9599e-04 - mae: 0.0207 - lr: 5.0000e-04
# Epoch 16/400
# 67/67 [==============================] - 1s 17ms/step - loss: 9.8541e-04 - mae: 0.0206 - lr: 5.0000e-04
# Epoch 17/400
400
# 67/67 [==============================] - 1s 17ms/step - loss: 4.6188e-04 - mae: 0.0146 - lr: 2.5523e-05
# Epoch 398/400
# 67/67 [==============================] - 1s 17ms/step - loss: 4.8558e-04 - mae: 0.0147 - lr: 2.5523e-05
# Epoch 399/400
# 67/67 [==============================] - 1s 18ms/step - loss: 4.7706e-04 - mae: 0.0146 - lr: 2.5523e-05
# Epoch 400/400
# 67/67 [==============================] - 1s 19ms/step - loss: 5.1036e-04 - mae: 0.0148 - lr: 2.5523e-05

# %%
print(rnn.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 200)               40400
#
#  dense_2 (Dense)             (None, 5)                 1005
#
# =================================================================
# Total params: 41,405
# Trainable params: 41,405
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Evaluating the forecast
#
# Now it is time to evaluate the performance of the forecast. For this we use the `compute_metrics` function:

# %% [markdown]
# At this point only the model that will perform the forecast is ready but we still need to compute the actual forecast.

# %% [markdown]
# Faster model forecasts
#
#
# - The dataset is windowed using `window_size` rather than `window_size + 1`
# - No shuffle should be used
# - No need to split the data into features and labels
# - A model is used to predict batches of the dataset

# %% [markdown]
# Now compute the actual forecast:

# %%
# Evaluate each model and the ensemble on the test set
# remember the last predicted value is not in the test set. It should be removed when producing y_hat series.

rnn_pred =  model_forecast(rnn, series_norm, G.WINDOW_SIZE).squeeze()
# Out:
# 75/75 [==============================] - 3s 17ms/step

# %%
rnn_pred = reverse_normalization(rnn_pred, series_train)

# %%
series_hat_rnn = rnn_pred

# %%
series_y_hat_rnn = np.array(list(series_hat_rnn[:-1]))

# %%
series_test = series_y[-G.SPLIT_TIME:]
series_test_hat_rnn_1 = series_y_hat_rnn[-G.SPLIT_TIME:,0]
series_test_hat_rnn_2 = series_y_hat_rnn[-G.SPLIT_TIME:-1,1]
series_test_hat_rnn_3 = series_y_hat_rnn[-G.SPLIT_TIME:-2,2]
series_test_hat_rnn_4 = series_y_hat_rnn[-G.SPLIT_TIME:-3,3]
series_test_hat_rnn_5 = series_y_hat_rnn[-G.SPLIT_TIME:-4,4]

# %%
# Plot the forecast

plt.figure(figsize=(10, 6))

plt.plot(np.arange( 1, len(time_test)+1 ), series_test, linestyle='-', color='blue')

plt.plot(np.arange( 1, len(time_test)+1 ), series_test_hat_rnn_1, linestyle='-', color='Red')

plt.plot(np.arange( 3, len(time_test)+1 ), series_test_hat_rnn_3, linestyle='--', color='Orange')

plt.plot(np.arange( 5, len(time_test)+1 ), series_test_hat_rnn_5, linestyle=':', color='Green')

plt.ylabel("Index Value")
plt.xlabel("Time Step")
plt.title("SSE test set prediction with RNN")
legend_drawn_flag = True
plt.legend(["Original Value (SSE)", "1-step forecasting","3-step forecasting","5-step forecasting"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/rnn_forecasts_SSE.tif")

# %%
rmse_rnn_1, mae_rnn_1, mape_rnn_1= compute_metrics(series_test, series_test_hat_rnn_1)

print(f"rmse: {rmse_rnn_1:.2f}, mae: {mae_rnn_1:.2f} , mape: {mape_rnn_1:.2f} for 1-step forecast")
# Out:
# rmse: 35.98, mae: 25.15 , mape: 0.86 for 1-step forecast

# %%
smape_rnn_1= smape(series_test, series_test_hat_rnn_1)

print(f"smape: {smape_rnn_1:.2f} for 1-step forecast")
# Out:
# smape: 0.86 for 1-step forecast

# %%
rmse_rnn_2, mae_rnn_2, mape_rnn_2= compute_metrics(series_test[1:], series_test_hat_rnn_2)

print(f"rmse: {rmse_rnn_2:.2f}, mae: {mae_rnn_2:.2f} , mape: {mape_rnn_2:.2f} for 2-step forecast")
# Out:
# rmse: 52.71, mae: 38.09 , mape: 1.30 for 2-step forecast

# %%
smape_rnn_2= smape(series_test[1:], series_test_hat_rnn_2)

print(f"smape: {smape_rnn_2:.2f} for 2-step forecast")
# Out:
# smape: 1.30 for 2-step forecast

# %%
rmse_rnn_3, mae_rnn_3, mape_rnn_3= compute_metrics(series_test[2:], series_test_hat_rnn_3)

print(f"rmse: {rmse_rnn_3:.2f}, mae: {mae_rnn_3:.2f} , mape: {mape_rnn_3:.2f} for 3-step forecast")
# Out:
# rmse: 64.96, mae: 47.70 , mape: 1.62 for 3-step forecast

# %%
smape_rnn_3= smape(series_test[2:], series_test_hat_rnn_3)

print(f"smape: {smape_rnn_3:.2f} for 3-step forecast")
# Out:
# smape: 1.62 for 3-step forecast

# %%
rmse_rnn_4, mae_rnn_4, mape_rnn_4= compute_metrics(series_test[3:], series_test_hat_rnn_4)

print(f"rmse: {rmse_rnn_4:.2f}, mae: {mae_rnn_4:.2f} , mape: {mape_rnn_4:.2f} for 4-step forecast")
# Out:
# rmse: 75.88, mae: 54.76 , mape: 1.86 for 4-step forecast

# %%
smape_rnn_4= smape(series_test[3:], series_test_hat_rnn_4)

print(f"smape: {smape_rnn_4:.2f} for 4-step forecast")
# Out:
# smape: 1.86 for 4-step forecast

# %%
rmse_rnn_5, mae_rnn_5, mape_rnn_5= compute_metrics(series_test[4:], series_test_hat_rnn_5)

print(f"rmse: {rmse_rnn_5:.2f}, mae: {mae_rnn_5:.2f} , mape: {mape_rnn_5:.2f} for 5-step forecast")
# Out:
# rmse: 86.63, mae: 62.93 , mape: 2.14 for 5-step forecast

# %%
smape_rnn_5= smape(series_test[4:], series_test_hat_rnn_5)

print(f"smape: {smape_rnn_5:.2f} for 5-step forecast")
# Out:
# smape: 2.13 for 5-step forecast

# %%
# Save_weights model

rnn.save_weights("/content/gdrive/MyDrive/Multistage/SSE/models/rnn_SSE_MIMO.h5", overwrite=True, save_format=None, options=None)

# %%
# Save predicted values

np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/rnn_predicted_test_SSE_1.csv", 
           series_test_hat_rnn_1.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/rnn_predicted_test_SSE_2.csv", 
           series_test_hat_rnn_2.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/rnn_predicted_test_SSE_3.csv", 
           series_test_hat_rnn_3.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/rnn_predicted_test_SSE_4.csv", 
           series_test_hat_rnn_4.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/rnn_predicted_test_SSE_5.csv", 
           series_test_hat_rnn_5.T, delimiter=",")


np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/rnn_predicted_whole_SSE.csv", 
           series_y_hat_rnn.T, delimiter=",")

# %% [markdown]
# ## CNN-LSTM

# %%
def CNN_LSTM():
   
    model = tf.keras.models.Sequential([
          tf.keras.layers.Conv1D(filters=256, kernel_size=2,
                                 strides=1,
                                 activation="relu",
                                 padding='causal',
                                 input_shape=[G.WINDOW_SIZE, 1]),
          tf.keras.layers.MaxPooling1D(pool_size=2, strides=1, padding="same"),
          tf.keras.layers.LSTM(200),
          tf.keras.layers.Dense(5)
    ])
    learning_rate = 0.0005
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=tf.keras.losses.MeanSquaredError(),
        metrics=["mae"])

    return model

# %% [markdown]
# ### Model training

# %%
with strategy.scope():
  cnn_lstm = CNN_LSTM()
    # Fit with the entire dataset.
cnn_lstm.fit(train_set_five_step, epochs=400,callbacks = [reduce_lr])
# Out:
# Epoch 1/400
# 67/67 [==============================] - 8s 40ms/step - loss: 0.0154 - mae: 0.0833 - lr: 5.0000e-04
# Epoch 2/400
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0045 - mae: 0.0439 - lr: 5.0000e-04
# Epoch 3/400
# 67/67 [==============================] - 2s 22ms/step - loss: 0.0014 - mae: 0.0242 - lr: 5.0000e-04
# Epoch 4/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0227 - lr: 5.0000e-04
# Epoch 5/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0233 - lr: 5.0000e-04
# Epoch 6/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0234 - lr: 5.0000e-04
# Epoch 7/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0013 - mae: 0.0240 - lr: 5.0000e-04
# Epoch 8/400
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0237 - lr: 5.0000e-04
# Epoch 9/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0237 - lr: 5.0000e-04
# Epoch 10/400
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0013 - mae: 0.0238 - lr: 4.7500e-04
# Epoch 11/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0012 - mae: 0.0231 - lr: 4.7500e-04
# Epoch 12/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0011 - mae: 0.0214 - lr: 4.7500e-04
# Epoch 13/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0010 - mae: 0.0210 - lr: 4.7500e-04
# Epoch 14/400
# 67/67 [==============================] - 1s 22ms/step - loss: 0.0012 - mae: 0.0232 - lr: 4.7500e-04
# Epoch 15/400
# 67/67 [==============================] - 1s 21ms/step - loss: 0.
400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.9366e-04 - mae: 0.0137 - lr: 2.4247e-05
# Epoch 372/400
# 67/67 [==============================] - 2s 22ms/step - loss: 3.9524e-04 - mae: 0.0137 - lr: 2.4247e-05
# Epoch 373/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9351e-04 - mae: 0.0137 - lr: 2.4247e-05
# Epoch 374/400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.9530e-04 - mae: 0.0137 - lr: 2.4247e-05
# Epoch 375/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9351e-04 - mae: 0.0137 - lr: 2.3035e-05
# Epoch 376/400
# 67/67 [==============================] - 2s 22ms/step - loss: 3.9434e-04 - mae: 0.0136 - lr: 2.3035e-05
# Epoch 377/400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.9253e-04 - mae: 0.0136 - lr: 2.3035e-05
# Epoch 378/400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.9346e-04 - mae: 0.0136 - lr: 2.3035e-05
# Epoch 379/400
# 67/67 [==============================] - 2s 22ms/step - loss: 3.9245e-04 - mae: 0.0136 - lr: 2.3035e-05
# Epoch 380/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9281e-04 - mae: 0.0136 - lr: 2.1883e-05
# Epoch 381/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9189e-04 - mae: 0.0136 - lr: 2.1883e-05
# Epoch 382/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9181e-04 - mae: 0.0136 - lr: 2.1883e-05
# Epoch 383/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9142e-04 - mae: 0.0136 - lr: 2.1883e-05
# Epoch 384/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9120e-04 - mae: 0.0136 - lr: 2.1883e-05
# Epoch 385/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9275e-04 - mae: 0.0137 - lr: 2.1883e-05
# Epoch 386/400
# 67/67 [==============================] - 2s 22ms/step - loss: 3.9154e-04 - mae: 0.0136 - lr: 2.1883e-05
# Epoch 387/400
# 67/67 [==============================] - 2s 22ms/step - loss: 3.9538e-04 - mae: 0.0137 - lr: 2.1883e-05
# Epoch 388/400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.9215e-04 - mae: 0.0137 - lr: 2.0789e-05
# Epoch 389/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9502e-04 - mae: 0.0137 - lr: 2.0789e-05
# Epoch 390/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9055e-04 - mae: 0.0136 - lr: 2.0789e-05
# Epoch 391/400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.9289e-04 - mae: 0.0137 - lr: 2.0789e-05
# Epoch 392/400
# 67/67 [==============================] - 2s 23ms/step - loss: 3.8999e-04 - mae: 0.0136 - lr: 2.0789e-05
# Epoch 393/400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.9294e-04 - mae: 0.0137 - lr: 1.9750e-05
# Epoch 394/400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.8918e-04 - mae: 0.0136 - lr: 1.9750e-05
# Epoch 395/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.9176e-04 - mae: 0.0136 - lr: 1.9750e-05
# Epoch 396/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.8912e-04 - mae: 0.0136 - lr: 1.9750e-05
# Epoch 397/400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.9132e-04 - mae: 0.0136 - lr: 1.9750e-05
# Epoch 398/400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.8871e-04 - mae: 0.0136 - lr: 1.8762e-05
# Epoch 399/400
# 67/67 [==============================] - 1s 22ms/step - loss: 3.8968e-04 - mae: 0.0136 - lr: 1.8762e-05
# Epoch 400/400
# 67/67 [==============================] - 1s 21ms/step - loss: 3.8700e-04 - mae: 0.0136 - lr: 1.8762e-05

# %%
print(cnn_lstm.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 50, 256)           768
#
#  max_pooling1d (MaxPooling1D  (None, 50, 256)          0
#  )
#
#  lstm_2 (LSTM)               (None, 200)               365600
#
#  dense_3 (Dense)             (None, 5)                 1005
#
# =================================================================
# Total params: 367,373
# Trainable params: 367,373
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Evaluating the forecast
#
# Now it is time to evaluate the performance of the forecast. For this we use the `compute_metrics` function:

# %% [markdown]
# At this point only the model that will perform the forecast is ready but we still need to compute the actual forecast.

# %% [markdown]
# Faster model forecasts
#
#
# - The dataset is windowed using `window_size` rather than `window_size + 1`
# - No shuffle should be used
# - No need to split the data into features and labels
# - A model is used to predict batches of the dataset

# %% [markdown]
# Now compute the actual forecast:

# %%
# Evaluate each model and the ensemble on the test set
# remember the last predicted value is not in the test set. It should be removed when producing y_hat series.

cnn_lstm_pred =  model_forecast(cnn_lstm, series_norm, G.WINDOW_SIZE).squeeze()
# Out:
# 75/75 [==============================] - 4s 17ms/step

# %%
cnn_lstm_pred = reverse_normalization(cnn_lstm_pred, series_train)

# %%
series_hat_cnn_lstm = cnn_lstm_pred

# %%
series_y_hat_cnn_lstm = np.array(list(series_hat_cnn_lstm[:-1]))

# %%
series_test = series_y[-G.SPLIT_TIME:]
series_test_hat_cnn_lstm_1 = series_y_hat_cnn_lstm[-G.SPLIT_TIME:,0]
series_test_hat_cnn_lstm_2 = series_y_hat_cnn_lstm[-G.SPLIT_TIME:-1,1]
series_test_hat_cnn_lstm_3 = series_y_hat_cnn_lstm[-G.SPLIT_TIME:-2,2]
series_test_hat_cnn_lstm_4 = series_y_hat_cnn_lstm[-G.SPLIT_TIME:-3,3]
series_test_hat_cnn_lstm_5 = series_y_hat_cnn_lstm[-G.SPLIT_TIME:-4,4]

# %%
# Plot the forecast

plt.figure(figsize=(10, 6))

plt.plot(np.arange( 1, len(time_test)+1 ), series_test, linestyle='-', color='blue')

plt.plot(np.arange( 1, len(time_test)+1 ), series_test_hat_cnn_lstm_1, linestyle='-', color='Red')

plt.plot(np.arange( 3, len(time_test)+1 ), series_test_hat_cnn_lstm_3, linestyle='--', color='Orange')

plt.plot(np.arange( 5, len(time_test)+1 ), series_test_hat_cnn_lstm_5, linestyle=':', color='Green')

plt.ylabel("Index Value")
plt.xlabel("Time Step")
plt.title("SSE test set prediction with CNN-LSTM")
legend_drawn_flag = True
plt.legend(["Original Value (SSE)", "1-step forecasting","3-step forecasting","5-step forecasting"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/cnn_lstm_forecasts_SSE.tif")

# %%
rmse_cnn_lstm_1, mae_cnn_lstm_1, mape_cnn_lstm_1= compute_metrics(series_test, series_test_hat_cnn_lstm_1)

print(f"rmse: {rmse_cnn_lstm_1:.2f}, mae: {mae_cnn_lstm_1:.2f} , mape: {mape_cnn_lstm_1:.2f} for 1-step forecast")
# Out:
# rmse: 34.30, mae: 23.60 , mape: 0.81 for 1-step forecast

# %%
smape_cnn_lstm_1= smape(series_test, series_test_hat_cnn_lstm_1)

print(f"smape: {smape_cnn_lstm_1:.2f} for 1-step forecast")
# Out:
# smape: 0.81 for 1-step forecast

# %%
rmse_cnn_lstm_2, mae_cnn_lstm_2, mape_cnn_lstm_2= compute_metrics(series_test[1:], series_test_hat_cnn_lstm_2)

print(f"rmse: {rmse_cnn_lstm_2:.2f}, mae: {mae_cnn_lstm_2:.2f} , mape: {mape_cnn_lstm_2:.2f} for 2-step forecast")
# Out:
# rmse: 49.88, mae: 36.20 , mape: 1.23 for 2-step forecast

# %%
smape_cnn_lstm_2= smape(series_test[1:], series_test_hat_cnn_lstm_2)

print(f"smape: {smape_cnn_lstm_2:.2f} for 2-step forecast")
# Out:
# smape: 1.23 for 2-step forecast

# %%
rmse_cnn_lstm_3, mae_cnn_lstm_3, mape_cnn_lstm_3= compute_metrics(series_test[2:], series_test_hat_cnn_lstm_3)

print(f"rmse: {rmse_cnn_lstm_3:.2f}, mae: {mae_cnn_lstm_3:.2f} , mape: {mape_cnn_lstm_3:.2f} for 3-step forecast")
# Out:
# rmse: 61.72, mae: 45.15 , mape: 1.53 for 3-step forecast

# %%
smape_cnn_lstm_3= smape(series_test[2:], series_test_hat_cnn_lstm_3)

print(f"smape: {smape_cnn_lstm_3:.2f} for 3-step forecast")
# Out:
# smape: 1.53 for 3-step forecast

# %%
rmse_cnn_lstm_4, mae_cnn_lstm_4, mape_cnn_lstm_4= compute_metrics(series_test[3:], series_test_hat_cnn_lstm_4)

print(f"rmse: {rmse_cnn_lstm_4:.2f}, mae: {mae_cnn_lstm_4:.2f} , mape: {mape_cnn_lstm_4:.2f} for 4-step forecast")
# Out:
# rmse: 72.45, mae: 52.53 , mape: 1.78 for 4-step forecast

# %%
smape_cnn_lstm_4= smape(series_test[3:], series_test_hat_cnn_lstm_4)

print(f"smape: {smape_cnn_lstm_4:.2f} for 4-step forecast")
# Out:
# smape: 1.78 for 4-step forecast

# %%
rmse_cnn_lstm_5, mae_cnn_lstm_5, mape_cnn_lstm_5= compute_metrics(series_test[4:], series_test_hat_cnn_lstm_5)

print(f"rmse: {rmse_cnn_lstm_5:.2f}, mae: {mae_cnn_lstm_5:.2f} , mape: {mape_cnn_lstm_5:.2f} for 5-step forecast")
# Out:
# rmse: 82.27, mae: 59.64 , mape: 2.03 for 5-step forecast

# %%
smape_cnn_lstm_5= smape(series_test[4:], series_test_hat_cnn_lstm_5)

print(f"smape: {smape_cnn_lstm_5:.2f} for 5-step forecast")
# Out:
# smape: 2.03 for 5-step forecast

# %%
# Save_weights model

cnn_lstm.save_weights("/content/gdrive/MyDrive/Multistage/SSE/models/cnn_lstm_SSE_MIMO.h5", overwrite=True, save_format=None, options=None)

# %%
# Save predicted values

np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/cnn_lstm_predicted_test_SSE_1.csv", 
           series_test_hat_cnn_lstm_1.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/cnn_lstm_predicted_test_SSE_2.csv", 
           series_test_hat_cnn_lstm_2.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/cnn_lstm_predicted_test_SSE_3.csv", 
           series_test_hat_cnn_lstm_3.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/cnn_lstm_predicted_test_SSE_4.csv", 
           series_test_hat_cnn_lstm_4.T, delimiter=",")
np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/cnn_lstm_predicted_test_SSE_5.csv", 
           series_test_hat_cnn_lstm_5.T, delimiter=",")


np.savetxt("/content/gdrive/MyDrive/Multistage/SSE/files/cnn_lstm_predicted_whole_SSE.csv", 
           series_y_hat_cnn_lstm.T, delimiter=",")

# %% [markdown]
# # Plot together

# %%
# Plot the forecast

plt.figure(figsize=(10, 6))

plt.plot(np.arange( 1, len(time_test)+1 ), series_test, linestyle='-', color='blue')

plt.plot(np.arange( 1, len(time_test)+1 ), series_test_hat_capsnet_lstm_1, linestyle='-', color='Red')

plt.plot(np.arange( 1, len(time_test)+1 ), series_test_hat_lstm_1, linestyle='--', color='Orange')

plt.plot(np.arange( 1, len(time_test)+1 ), series_test_hat_rnn_1, linestyle=':', color='Green')

plt.plot(np.arange( 1, len(time_test)+1 ), series_test_hat_cnn_lstm_1, linestyle='-.', color='Grey')

plt.ylabel("Index Value")
plt.xlabel("Time Step")
plt.title("Comparison of 1-step forecasting for SSE")
legend_drawn_flag = True
plt.legend(["Original Value (SSE)", "CapsNet-LSTM","LSTM","RNN","CNN-LSTM"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/comparison_forecasts_1_step_SSE.tif")

# %%
# Plot the forecast

plt.figure(figsize=(10, 6))

plt.plot(np.arange( 1, len(time_test)+1 ), series_test, linestyle='-', color='blue')

plt.plot(np.arange( 3, len(time_test)+1 ), series_test_hat_capsnet_lstm_3, linestyle='-', color='Red')

plt.plot(np.arange( 3, len(time_test)+1 ), series_test_hat_lstm_3, linestyle='--', color='Orange')

plt.plot(np.arange( 3, len(time_test)+1 ), series_test_hat_rnn_3, linestyle=':', color='Green')

plt.plot(np.arange( 3, len(time_test)+1 ), series_test_hat_cnn_lstm_3, linestyle='-.', color='Grey')

plt.ylabel("Index Value")
plt.xlabel("Time Step")
plt.title("Comparison of 3-step forecasting for SSE")
legend_drawn_flag = True
plt.legend(["Original Value (SSE)", "CapsNet-LSTM","LSTM","RNN","CNN-LSTM"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/comparison_forecasts_3_step_SSE.tif")

# %%
# Plot the forecast

plt.figure(figsize=(10, 6))

plt.plot(np.arange( 1, len(time_test)+1 ), series_test, linestyle='-', color='blue')

plt.plot(np.arange( 5, len(time_test)+1 ), series_test_hat_capsnet_lstm_5, linestyle='-', color='Red')

plt.plot(np.arange( 5, len(time_test)+1 ), series_test_hat_lstm_5, linestyle='--', color='Orange')

plt.plot(np.arange( 5, len(time_test)+1 ), series_test_hat_rnn_5, linestyle=':', color='Green')

plt.plot(np.arange( 5, len(time_test)+1 ), series_test_hat_cnn_lstm_5, linestyle='-.', color='Grey')

plt.ylabel("Index Value")
plt.xlabel("Time Step")
plt.title("Comparison of 5-step forecasting for SSE")
legend_drawn_flag = True
plt.legend(["Original Value (SSE)", "CapsNet-LSTM","LSTM","RNN","CNN-LSTM"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/comparison_forecasts_5_step_SSE.tif")

# %% [markdown]
# RMSE:

# %%
rmse_capsnet_lstm = [rmse_capsnet_lstm_1,rmse_capsnet_lstm_2,rmse_capsnet_lstm_3,rmse_capsnet_lstm_4,rmse_capsnet_lstm_5]

# %%
rmse_lstm = [rmse_lstm_1,rmse_lstm_2,rmse_lstm_3,rmse_lstm_4,rmse_lstm_5]

# %%
rmse_rnn = [rmse_rnn_1,rmse_rnn_2,rmse_rnn_3,rmse_rnn_4,rmse_rnn_5]

# %%
rmse_cnn_lstm = [rmse_cnn_lstm_1,rmse_cnn_lstm_2,rmse_cnn_lstm_3,rmse_cnn_lstm_4,rmse_cnn_lstm_5]

# %%
plt.figure(figsize=(10, 6))
plt.rcParams['font.size'] = '16'
plt.plot(np.arange( 1, 6 ), rmse_capsnet_lstm,linestyle='-', color='blue')
plt.plot(np.arange( 1, 6 ), rmse_lstm,linestyle='-', color='Red')
plt.plot(np.arange( 1, 6 ), rmse_rnn,linestyle='--', color='Orange')
plt.plot(np.arange( 1, 6 ), rmse_cnn_lstm,linestyle=':', color='Green')

plt.ylabel("RMSE Value")
plt.xlabel("Forecasting horizon (day)")
plt.xticks(np.arange(1, 6, 1))
plt.title("Comparison of RMSE values for multi step ahead forecasting")
legend_drawn_flag = True
plt.legend(["CapsNet-LSTM","LSTM","RNN","CNN-LSTM)"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/rmse_5_steps_SSE.tif")

# %% [markdown]
# MAE:

# %%
mae_capsnet_lstm = [mae_capsnet_lstm_1,mae_capsnet_lstm_2,mae_capsnet_lstm_3,mae_capsnet_lstm_4,mae_capsnet_lstm_5]

# %%
mae_lstm = [mae_lstm_1,mae_lstm_2,mae_lstm_3,mae_lstm_4,mae_lstm_5]

# %%
mae_rnn = [mae_rnn_1,mae_rnn_2,mae_rnn_3,mae_rnn_4,mae_rnn_5]

# %%
mae_cnn_lstm = [mae_cnn_lstm_1,mae_cnn_lstm_2,mae_cnn_lstm_3,mae_cnn_lstm_4,mae_cnn_lstm_5]

# %%
plt.figure(figsize=(10, 6))
plt.rcParams['font.size'] = '16'
plt.plot(np.arange( 1, 6 ), mae_capsnet_lstm,linestyle='-', color='blue')
plt.plot(np.arange( 1, 6 ), mae_lstm,linestyle='-', color='Red')
plt.plot(np.arange( 1, 6 ), mae_rnn,linestyle='--', color='Orange')
plt.plot(np.arange( 1, 6 ), mae_cnn_lstm,linestyle=':', color='Green')

plt.ylabel("MAE Value")
plt.xlabel("Forecasting horizon (day)")
plt.xticks(np.arange(1, 6, 1))
plt.title("Comparison of MAE values for multi step ahead forecasting")
legend_drawn_flag = True
plt.legend(["CapsNet-LSTM","LSTM","RNN","CNN-LSTM)"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/mae_5_steps_SSE.tif")

# %% [markdown]
# MAPE:

# %%
mape_capsnet_lstm = [mape_capsnet_lstm_1,mape_capsnet_lstm_2,mape_capsnet_lstm_3,mape_capsnet_lstm_4,mape_capsnet_lstm_5]

# %%
mape_lstm = [mape_lstm_1,mape_lstm_2,mape_lstm_3,mape_lstm_4,mape_lstm_5]

# %%
mape_rnn = [mape_rnn_1,mape_rnn_2,mape_rnn_3,mape_rnn_4,mape_rnn_5]

# %%
mape_cnn_lstm = [mape_cnn_lstm_1,mape_cnn_lstm_2,mape_cnn_lstm_3,mape_cnn_lstm_4,mape_cnn_lstm_5]

# %%
plt.figure(figsize=(10, 6))
plt.rcParams['font.size'] = '16'
plt.plot(np.arange( 1, 6 ), mape_capsnet_lstm,linestyle='-', color='blue')
plt.plot(np.arange( 1, 6 ), mape_lstm,linestyle='-', color='Red')
plt.plot(np.arange( 1, 6 ), mape_rnn,linestyle='--', color='Orange')
plt.plot(np.arange( 1, 6 ), mape_cnn_lstm,linestyle=':', color='Green')

plt.ylabel("MAPE Value")
plt.xlabel("Forecasting horizon (day)")
plt.xticks(np.arange(1, 6, 1))
plt.title("Comparison of MAPE values for multi step ahead forecasting")
legend_drawn_flag = True
plt.legend(["CapsNet-LSTM","LSTM","RNN","CNN-LSTM)"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/mape_5_steps_SSE.tif")

# %%
smape_capsnet_lstm = [smape_capsnet_lstm_1,smape_capsnet_lstm_2,smape_capsnet_lstm_3,smape_capsnet_lstm_4,smape_capsnet_lstm_5]

# %%
smape_lstm = [smape_lstm_1,smape_lstm_2,smape_lstm_3,smape_lstm_4,smape_lstm_5]

# %%
smape_rnn = [smape_rnn_1,smape_rnn_2,smape_rnn_3,smape_rnn_4,smape_rnn_5]

# %%
smape_cnn_lstm = [smape_cnn_lstm_1,smape_cnn_lstm_2,smape_cnn_lstm_3,smape_cnn_lstm_4,smape_cnn_lstm_5]

# %%
plt.figure(figsize=(10, 6))
plt.rcParams['font.size'] = '16'
plt.plot(np.arange( 1, 6 ), smape_capsnet_lstm,linestyle='-', color='blue')
plt.plot(np.arange( 1, 6 ), smape_lstm,linestyle='-', color='Red')
plt.plot(np.arange( 1, 6 ), smape_rnn,linestyle='--', color='Orange')
plt.plot(np.arange( 1, 6 ), smape_cnn_lstm,linestyle=':', color='Green')

plt.ylabel("SMAPE Value")
plt.xlabel("Forecasting horizon (day)")
plt.xticks(np.arange(1, 6, 1))
plt.title("Comparison of SMAPE values for multi step ahead forecasting")
legend_drawn_flag = True
plt.legend(["CapsNet-LSTM","LSTM","RNN","CNN-LSTM)"], loc='upper left', frameon=legend_drawn_flag)
plt.savefig("/content/gdrive/MyDrive/Multistage/SSE/figures/smape_5_steps_SSE.tif")
